# %%
import pandas as pd

# %%
df = pd.read_csv(r'D:\hello_\name_1\name_1\Credit Card\notebooks\credit_card.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0           0      50000    1          2         1   57     -1      0     -1
# 1           1      50000    1          1         2   37      0      0      0
# 2           2     500000    1          1         2   29      0      0      0
# 3           3     100000    2          2         2   23      0     -1     -1
# 4           4     140000    2          3         1   28      0      0      2
#
#    PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
# ...

# %%
df.drop('Unnamed: 0' , axis=1 , inplace=True)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
df.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
i = 0
s = "Col"
d = {}

for col in df.columns:
    d[col] = f'{s}_{i}'
    i += 1

df.rename(columns=d, inplace=True)

# %%
df.columns
# Out:
# Index(['Col_0', 'Col_1', 'Col_2', 'Col_3', 'Col_4', 'Col_5', 'Col_6', 'Col_7',
#        'Col_8', 'Col_9', 'Col_10', 'Col_11', 'Col_12', 'Col_13', 'Col_14',
#        'Col_15', 'Col_16', 'Col_17', 'Col_18', 'Col_19', 'Col_20', 'Col_21',
#        'Col_22', 'Col_23'],
#       dtype='object')

# %%
df.head()
# Out:
#     Col_0  Col_1  Col_2  Col_3  Col_4  Col_5  Col_6  Col_7  Col_8  Col_9  ...  \
# 0   50000      1      2      1     57     -1      0     -1      0      0  ...
# 1   50000      1      1      2     37      0      0      0      0      0  ...
# 2  500000      1      1      2     29      0      0      0      0      0  ...
# 3  100000      2      2      2     23      0     -1     -1      0      0  ...
# 4  140000      2      3      1     28      0      0      2      0      0  ...
#
#    Col_14  Col_15  Col_16  Col_17  Col_18  Col_19  Col_20  Col_21  Col_22  \
# 0   20940   19146   19131    2000   36681   10000    9000     689     679
# 1   19394   19619   20024    2500    1815     657    1000    1000     800
# 2  542653  483003  473944   55000   40000   38000   20239   13750   13770
# 3     221    -159     567     380     601       0     581    1687    1542
# 4   12211   11793    3719    3329       0     432    1000    1000    1000
#
#    Col_23
# 0       0
# 1       0
# 2       0
# ...

# %%
import os

# %%
os.path.join('df.to_csv' , 'notebooks')
# Out:
# 'df.to_csv\\notebooks'

# %%
df.to_csv('notebooks.csv' , index=True)
